# %% [markdown]
# # Batch HYSPLIT untuk Pengisian Target Dataset
#
# Notebook ini versi bersih untuk memproses dataset gabungan gunung berapi secara looping batch.
#
# Output yang diisi otomatis per baris dataset:
# - `jarak_km`
# - `luas_km2`
# - `sudut_deg`
# - `radius_km`
#
# Catatan:
# - Runtime simulasi dipatok statis **1 jam** untuk semua baris.
# - Lokasi erupsi per baris diambil dari kolom `latitude` dan `longitude`.
# - Notebook ini tidak bergantung pada notebook lama.

# %%
import glob
import os
import subprocess
from datetime import datetime
from math import radians, cos, sin, asin, sqrt, atan2, degrees
from pathlib import Path

import numpy as np
import pandas as pd

# =========================================================
# KONFIGURASI UTAMA
# =========================================================
DATASET_PATH = Path("d:/Projects/volcanic_ash/simulation/dataset-java-ash.csv")
OUTPUT_PATH = Path("d:/Projects/volcanic_ash/simulation/java_hysplit_filled.csv")

HYSPLIT_EXE = "F:/HYSPLIT/exec/hycs_std.exe"
CON2ASC_EXE = "F:/HYSPLIT/exec/con2asc.exe"
WORKING_DIR = "F:/HYSPLIT/working"
METDATA_DIR = "F:/HYSPLIT/metdata"

# Runtime simulasi statis 1 jam
BATCH_RUNTIME_JAM = 2

# Parameter partikel/model default
EMISSION_RATE = 1000.0
PARTICLE_DIAMETER_UM = 30.0
PARTICLE_DENSITY_G_CM3 = 2.5
PARTICLE_SHAPE = 0.7
DRY_DEPOSITION_VEL = 0.01
WET_REMOVAL_COEF = 0.0
THRESHOLD_CONC = 1e-15
GRID_SPACING = 0.05
GRID_SPAN_LAT = 30.0
GRID_SPAN_LON = 30.0
TOP_OF_MODEL_M = 40000.0
VERTICAL_MOTION = 0

# Batch options
CHECKPOINT_EVERY = 50
MAX_ROWS = None  # set angka, misal 3, untuk uji cepat
OVERWRITE_OUTPUT = True

TARGET_COLS = ["jarak_km", "luas_km2", "sudut_deg", "radius_km"]
REQUIRED_INPUT_COLS = ["timestamp", "latitude", "longitude", "tinggi_letusan_m"]

# %%
def parse_row_timestamp(value):
    if pd.isna(value):
        raise ValueError("timestamp kosong")

    text = str(value).strip()
    formats = [
        "%Y-%m-%d %H:%M:%S UTC",
        "%Y-%m-%d %H:%M:%S",
        "%Y-%m-%d %H:%M",
    ]
    for fmt in formats:
        try:
            return datetime.strptime(text, fmt)
        except ValueError:
            continue

    dt = pd.to_datetime(text, utc=True, errors="coerce")
    if pd.isna(dt):
        raise ValueError(f"format timestamp tidak dikenali: {value}")
    return dt.to_pydatetime().replace(tzinfo=None)


def to_hysplit_timestamp(dt):
    return dt.strftime("%y %m %d %H")


def infer_gdas_met_file(dt):
    month = dt.strftime("%b").lower()
    # Modifikasi: Selalu gunakan tahun 25 (2025) dan minggu ke-1 (w1)
    yy = "25"
    week = 1
    return f"gdas1.{month}{yy}.w{week}"


def create_control_file(lat_sumber, lon_sumber, tinggi_letusan_m, timestamp, met_file):
    os.makedirs(WORKING_DIR, exist_ok=True)
    control_path = os.path.join(WORKING_DIR, "CONTROL")
    conc_level = max(float(tinggi_letusan_m), 1000.0)

    control_lines = [
        timestamp,
        "1",
        f"{lat_sumber} {lon_sumber} {tinggi_letusan_m}",
        str(BATCH_RUNTIME_JAM),
        str(VERTICAL_MOTION),
        f"{TOP_OF_MODEL_M}",
        "1",
        f"{METDATA_DIR}/",
        met_file,
        "1",
        "ASH",
        str(EMISSION_RATE),
        f"{BATCH_RUNTIME_JAM}.0",
        "00 00 00 00 00",
        "1",
        f"{lat_sumber} {lon_sumber}",
        f"{GRID_SPACING} {GRID_SPACING}",
        f"{GRID_SPAN_LAT} {GRID_SPAN_LON}",
        "./",
        "cdump",
        "1",
        f"{conc_level:.1f}",
        "00 00 00 00 00",
        "00 00 00 00 00",
        "00 01 00",
        "1",
        f"{PARTICLE_DIAMETER_UM} {PARTICLE_DENSITY_G_CM3} {PARTICLE_SHAPE}",
        f"{DRY_DEPOSITION_VEL} 0.0 0.0 0.0 0.0",
        f"{WET_REMOVAL_COEF} 0.0 0.0",
        "0.0",
        "0.0",
    ]

    with open(control_path, "w") as f:
        f.write("\n".join(control_lines) + "\n")


def run_hysplit_once(met_file):
    met_path = os.path.join(METDATA_DIR, met_file)
    if not os.path.exists(HYSPLIT_EXE):
        raise FileNotFoundError(f"Executable HYSPLIT tidak ditemukan: {HYSPLIT_EXE}")
    if not os.path.exists(met_path):
        raise FileNotFoundError(f"File meteo tidak ditemukan: {met_path}")

    result = subprocess.run(
        [HYSPLIT_EXE],
        cwd=WORKING_DIR,
        capture_output=True,
        text=True,
    )

    if result.returncode != 0:
        msg = result.stderr.strip() if result.stderr else "simulasi gagal"
        raise RuntimeError(msg)


def convert_cdump_to_txt():
    cdump_file = os.path.join(WORKING_DIR, "cdump")
    if not os.path.exists(cdump_file):
        raise FileNotFoundError(f"cdump tidak ditemukan: {cdump_file}")
    if not os.path.exists(CON2ASC_EXE):
        raise FileNotFoundError(f"con2asc.exe tidak ditemukan: {CON2ASC_EXE}")

    old_files = glob.glob(os.path.join(WORKING_DIR, "cdump_*"))
    for old_file in old_files:
        if os.path.isfile(old_file):
            os.remove(old_file)

    result = subprocess.run(
        [CON2ASC_EXE, "-i" + cdump_file],
        cwd=WORKING_DIR,
        capture_output=True,
        text=True,
    )
    if result.returncode != 0:
        msg = result.stderr.strip() if result.stderr else "konversi cdump gagal"
        raise RuntimeError(msg)

    converted_files = glob.glob(os.path.join(WORKING_DIR, "cdump_*"))
    converted_files = [f for f in converted_files if os.path.isfile(f) and not f.endswith(".txt")]
    if not converted_files:
        raise RuntimeError("file hasil konversi cdump_* tidak ditemukan")

    cdump_txt = os.path.join(WORKING_DIR, "cdump.txt")
    all_lines = []
    for conv_file in sorted(converted_files):
        with open(conv_file, "r") as f:
            all_lines.extend(f.readlines())

    with open(cdump_txt, "w") as f:
        f.writelines(all_lines)

    return cdump_txt

# %%
def haversine(lat1, lon1, lat2, lon2):
    R = 6371
    dlat = radians(lat2 - lat1)
    dlon = radians(lon2 - lon1)
    a = sin(dlat / 2) ** 2 + cos(radians(lat1)) * cos(radians(lat2)) * sin(dlon / 2) ** 2
    c = 2 * asin(sqrt(a))
    return R * c


def calculate_bearing(lat1, lon1, lat2, lon2):
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
    dlon = lon2 - lon1
    x = sin(dlon) * cos(lat2)
    y = cos(lat1) * sin(lat2) - sin(lat1) * cos(lat2) * cos(dlon)
    bearing = atan2(x, y)
    return (degrees(bearing) + 360) % 360


def parse_cdump_with_timestep(filepath):
    data_points = []
    with open(filepath, "r") as f:
        for line in f:
            stripped = line.strip()
            if not stripped or "DAY" in stripped:
                continue

            parts = stripped.split()
            numeric_values = []
            for part in parts:
                try:
                    numeric_values.append(float(part))
                except ValueError:
                    continue

            if len(numeric_values) >= 5:
                data_points.append({
                    "day": int(numeric_values[0]),
                    "hr": int(numeric_values[1]),
                    "lat": numeric_values[2],
                    "lon": numeric_values[3],
                    "concentration": numeric_values[4],
                })
    return data_points


def calculate_grid_area_km2(lats, lons):
    unique_lats = sorted(set(lats))
    unique_lons = sorted(set(lons))

    dlat_deg = abs(unique_lats[1] - unique_lats[0]) if len(unique_lats) >= 2 else 0.25
    dlon_deg = abs(unique_lons[1] - unique_lons[0]) if len(unique_lons) >= 2 else 0.25

    mean_lat = np.mean(unique_lats)
    dlat_km = dlat_deg * 111.32
    dlon_km = dlon_deg * 111.32 * cos(radians(abs(mean_lat)))
    return dlat_km * dlon_km


def analyze_cdump(cdump_txt, source_lat, source_lon, threshold_conc=THRESHOLD_CONC):
    raw_points = parse_cdump_with_timestep(cdump_txt)
    if len(raw_points) == 0:
        raise RuntimeError("cdump.txt tidak memiliki data")

    valid_points = []
    for p in raw_points:
        lat, lon, conc = p["lat"], p["lon"], p["concentration"]
        if -90 <= lat <= 90 and -180 <= lon <= 180 and conc > threshold_conc:
            valid_points.append(p)

    if len(valid_points) == 0:
        raise RuntimeError("tidak ada data konsentrasi di atas threshold")

    df_all = pd.DataFrame(valid_points)
    df_unique = df_all.groupby(["lat", "lon"]).agg(
        max_conc=("concentration", "max"),
        mean_conc=("concentration", "mean"),
        n_timesteps=("concentration", "count"),
    ).reset_index()

    distances = []
    bearings = []
    max_distance = 0.0

    for _, r in df_unique.iterrows():
        dist = haversine(source_lat, source_lon, r["lat"], r["lon"])
        bear = calculate_bearing(source_lat, source_lon, r["lat"], r["lon"])
        distances.append(dist)
        bearings.append(bear)
        if dist > max_distance:
            max_distance = dist

    df_unique["distance_km"] = distances

    jarak_km = float(max_distance)
    radius_km = float(df_unique["distance_km"].mean())

    rad_bearings = [radians(b) for b in bearings]
    mean_sin = np.mean([sin(r) for r in rad_bearings])
    mean_cos = np.mean([cos(r) for r in rad_bearings])
    sudut_deg = float(degrees(atan2(mean_sin, mean_cos)) % 360)

    grid_area_km2 = calculate_grid_area_km2(df_unique["lat"].values, df_unique["lon"].values)
    luas_km2 = float(len(df_unique) * grid_area_km2)

    return {
        "jarak_km": jarak_km,
        "luas_km2": luas_km2,
        "sudut_deg": sudut_deg,
        "radius_km": radius_km,
    }

# %%
def run_one_row(row):
    dt = parse_row_timestamp(row["timestamp"])
    
    # Konversi tahun ke 2025, dan tanggal > 7 ke tanggal 5
    new_day = 5 if dt.day >= 7 else dt.day
    dt = dt.replace(year=2025, day=new_day)
    
    lat = float(row["latitude"])
    lon = float(row["longitude"])
    tinggi = float(row["tinggi_letusan_m"])

    timestamp = to_hysplit_timestamp(dt)
    met_file = infer_gdas_met_file(dt)

    create_control_file(
        lat_sumber=lat,
        lon_sumber=lon,
        tinggi_letusan_m=tinggi,
        timestamp=timestamp,
        met_file=met_file,
    )

    run_hysplit_once(met_file)
    cdump_txt = convert_cdump_to_txt()
    metrics = analyze_cdump(cdump_txt, source_lat=lat, source_lon=lon, threshold_conc=THRESHOLD_CONC)
    return metrics


def fill_dataset_targets(dataset_path=DATASET_PATH, output_path=OUTPUT_PATH):
    if not dataset_path.exists():
        raise FileNotFoundError(f"dataset tidak ditemukan: {dataset_path}")

    if output_path.exists() and not OVERWRITE_OUTPUT:
        raise FileExistsError(f"output sudah ada: {output_path}")

    df = pd.read_csv(dataset_path)

    missing_inputs = [c for c in REQUIRED_INPUT_COLS if c not in df.columns]
    if missing_inputs:
        raise ValueError(f"kolom input wajib tidak ditemukan: {missing_inputs}")

    for col in TARGET_COLS:
        if col not in df.columns:
            df[col] = np.nan

    pending_mask = df[TARGET_COLS].isna().any(axis=1)
    pending_idx = df.index[pending_mask].tolist()

    if MAX_ROWS is not None:
        pending_idx = pending_idx[: int(MAX_ROWS)]

    print("=" * 70)
    print("BATCH FILL TARGET DATASET")
    print("=" * 70)
    print(f"Dataset         : {dataset_path}")
    print(f"Output          : {output_path}")
    print(f"Runtime simulasi: {BATCH_RUNTIME_JAM} jam")
    print(f"Total baris     : {len(df)}")
    print(f"Baris pending   : {len(pending_idx)}")

    success = 0
    failed = 0

    for n, idx in enumerate(pending_idx, start=1):
        row = df.loc[idx]
        rec_id = row.get("id", idx)
        volcano = row.get("volcano_filter", "unknown")

        print("\n" + "-" * 70)
        print(f"[{n}/{len(pending_idx)}] id={rec_id}, gunung={volcano}")

        try:
            metrics = run_one_row(row)
            for key, value in metrics.items():
                df.at[idx, key] = value

            success += 1
            print(
                f"OK: jarak={metrics['jarak_km']:.2f} km, "
                f"luas={metrics['luas_km2']:.2f} km2, "
                f"sudut={metrics['sudut_deg']:.2f} deg, "
                f"radius={metrics['radius_km']:.2f} km"
            )

            if n % CHECKPOINT_EVERY == 0:
                df.to_csv(output_path, index=False, encoding="utf-8-sig")
                print(f"Checkpoint tersimpan: {output_path}")

        except Exception as e:
            failed += 1
            print(f"Gagal: {e}")

    df.to_csv(output_path, index=False, encoding="utf-8-sig")

    print("\n" + "=" * 70)
    print("RINGKASAN")
    print("=" * 70)
    print(f"Berhasil: {success}")
    print(f"Gagal   : {failed}")
    print(f"Output  : {output_path}")

    return df


batch_df = fill_dataset_targets()
# Out:
# ======================================================================
# BATCH FILL TARGET DATASET
# ======================================================================
# Dataset         : d:\Projects\volcanic_ash\simulation\dataset-java-ash.csv
# Output          : d:\Projects\volcanic_ash\simulation\java_hysplit_filled.csv
# Runtime simulasi: 2 jam
# Total baris     : 1707
# Baris pending   : 1707
#
# ----------------------------------------------------------------------
# [1/1707] id=1, gunung=Merapi
# OK: jarak=32.51 km, luas=614.39 km2, sudut=303.26 deg, radius=18.30 km
#
# ----------------------------------------------------------------------
# [2/1707] id=2, gunung=Merapi
# OK: jarak=27.76 km, luas=460.79 km2, sudut=37.90 deg, radius=15.89 km
#
# ----------------------------------------------------------------------
# [3/1707] id=3, gunung=Merapi
# OK: jarak=44.63 km, luas=614.21 km2, sudut=265.64 deg, radius=23.93 km
#
# ----------------------------------------------------------------------
# [4/1707] id=4, gunung=Merapi
# OK: jarak=23.00 km, luas=184.29 km2, sudut=288.11 deg, radius=11.77 km
#
# ----------------------------------------------------------------------
# [5/1707] id=5, gunung=Merapi
# OK: jarak=39.16 km, luas=307.11 km2, sudut=270.46 deg, radius=20.81 km
#
# ----------------------------------------------------------------------
# [6/1707] id=6, gunung=Merapi
# OK: jarak=50.10 km, luas=368.53 km2, sudut=269.26 deg, radius=25.24 km
#
# ----------------------------------------------------------------------
# [7/1707] id=7, gunung=Merapi
# OK: jarak=50.99 km, luas=368.51 km2, sudut=265.94 deg, radius=26.41 km
#
# ----------------------------------------------------------------------
# [8/1707] id=8, gunung=Merapi
# OK: jarak=50.99 km, luas=368.51 km2, sudut=265.94 deg, radius=26.41 km
#
# ----------------------------------------------------------------------
# [9/1707] id=9, gunung=Merapi
# OK: jarak=39.23 km, luas=337.86 km2, sudut=278.43 deg, radius=21.97 km
#
# ----------------------------------------------------------------------
# [10/1707] id=10, gunung=Merapi
# OK: jarak=46.09 km, luas=1351.97 km2, sudut=341.66 deg, radius=25.84 km
#
# ----------------------------------------------------------------------
# [11/1707] id=11, gunung=Merapi
# OK: jarak=35.72 km, luas=645.11 km2, sudut=305.71 deg, radius=19.84 km
#
# ----------------------------------------------------------------------
# [12/1707] id=12, gunung=Merapi
# OK: jarak=35.72 km, luas=368.63 km2, sudut=305.47 deg, radius=19.96 km
#
# ----------------------------------------------------------------------
# [13/1707] id=13, gunung=Merapi
# OK: jarak=31.62 km, luas=737.27 km2, sudut=311.30 deg, radius=18.18 km
#
# ----------------------------------------------------------------------
# [14/1707] id=14, gunung=Merapi
# OK: jarak=30.00 km, luas=245.73 km2, sudut=295.31 deg, radius=15.31 km
#
# ----------------------------------------------------------------------
# [15/1707] id=15, gunung=Merapi
# Gagal: cdump.txt tidak memiliki data
#
# ----------------------------------------------------------------------
# [16/1707] id=16, gunung=Merapi
# OK: jarak=150.12 km, luas=1657.70 km2, sudut=254.81 deg, radius=86.42 km
#
# ----------------------------------------------------------------------
# [17/1707] id=17, gunung=Merapi
# OK: jarak=35.16 km, luas=307.16 km2, sudut=295.53 deg, radius=17.79 km
#
# ----------------------------------------------------------------------
# [18/1707] id=18, gunung=Merapi
# OK: jarak=104.94 km, luas=3071.25 km2, sudut=272.43 deg, radius=52.58 km
#
# ----------------------------------------------------------------------
# [19/1707] id=19, gunung=Merapi
# OK: jarak=54.46 km, luas=552.70 km2, sudut=253.75 deg, radius=28.84 km
#
# ----------------------------------------------------------------------
# [20/1707] id=20, gunung=Merapi
# OK: jarak=101.54 km, luas=767.50 km2, sudut=249.91 deg, radius=50.75 km
#
# ----------------------------------------------------------------------
# [21/1707] id=21, gunung=Merapi
# OK: jarak=69.90 km, luas=675.52 km2, sudut=258.61 deg, radius=38.64 km
#
# ----------------------------------------------------------------------
# [22/1707] id=22, gunung=Merapi
# OK: jarak=58.85 km, luas=552.57 km2, sudut=229.12 deg, radius=30.62 km
#
# ----------------------------------------------------------------------
# [23/1707] id=23, gunung=Merapi
# OK: jarak=63.15 km, luas=522.20 km2, sudut=286.29 deg, radius=33.25 km
#
# ----------------------------------------------------------------------
# [24/1707] id=24, gunung=Merapi
# OK: jarak=132.59 km, luas=2180.08 km2, sudut=265.77 deg, radius=77.51 km
#
# ----------------------------------------------------------------------
# [25/1707] id=25, gunung=Merapi
# OK: jarak=189.74 km, luas=7346.08 km2, sudut=287.75 deg, radius=119.08 km
#
# ----------------------------------------------------------------------
# [26/1707] id=26, gunung=Merapi
# OK: jarak=22.76 km, luas=184.23 km2, sudut=193.70 deg, radius=12.97 km
#
# ----------------------------------------------------------------------
# [27/1707] id=27, gunung=Merapi
# OK: jarak=109.55 km, luas=3344.89 km2, sudut=232.33 deg, radius=60.92 km
#
# ----------------------------------------------------------------------
# [28/1707] id=28, gunung=Merapi
# OK: jarak=160.40 km, luas=2825.39 km2, sudut=268.91 deg, radius=95.60 km
#
# ----------------------------------------------------------------------
# [29/1707] id=29, gunung=Merapi
# OK: jarak=79.12 km, luas=1013.16 km2, sudut=248.67 deg, radius=40.25 km
#
# ----------------------------------------------------------------------
# [30/1707] id=30, gunung=Merapi
# OK: jarak=28.28 km, luas=276.40 km2, sudut=267.53 deg, radius=15.28 km
#
# ----------------------------------------------------------------------
# [31/1707] id=31, gunung=Merapi
# OK: jarak=78.61 km, luas=1043.67 km2, sudut=233.12 deg, radius=36.08 km
#
# ----------------------------------------------------------------------
# [32/1707] id=32, gunung=Merapi
# OK: jarak=41.93 km, luas=460.77 km2, sudut=63.78 deg, radius=21.61 km
#
# ----------------------------------------------------------------------
# [33/1707] id=33, gunung=Merapi
# OK: jarak=58.82 km, luas=583.30 km2, sudut=236.61 deg, radius=31.27 km
#
# ----------------------------------------------------------------------
# [34/1707] id=34, gunung=Merapi
# OK: jarak=50.99 km, luas=399.22 km2, sudut=262.06 deg, radius=26.41 km
#
# ----------------------------------------------------------------------
# [35/1707] id=35, gunung=Merapi
# OK: jarak=67.24 km, luas=522.05 km2, sudut=264.97 deg, radius=33.80 km
#
# ----------------------------------------------------------------------
# [36/1707] id=36, gunung=Merapi
# OK: jarak=129.14 km, luas=4112.07 km2, sudut=238.90 deg, radius=61.70 km
#
# ----------------------------------------------------------------------
# [37/1707] id=37, gunung=Merapi
# OK: jarak=101.43 km, luas=920.89 km2, sudut=241.69 deg, radius=50.90 km
#
# ----------------------------------------------------------------------
# [38/1707] id=38, gunung=Merapi
# OK: jarak=89.06 km, luas=1258.99 km2, sudut=260.20 deg, radius=42.40 km
#
# ----------------------------------------------------------------------
# [39/1707] id=39, gunung=Merapi
# OK: jarak=160.47 km, luas=2027.26 km2, sudut=272.80 deg, radius=94.77 km
#
# ----------------------------------------------------------------------
# [40/1707] id=40, gunung=Merapi
# OK: jarak=30.00 km, luas=245.73 km2, sudut=287.81 deg, radius=16.12 km
#
# ----------------------------------------------------------------------
# [41/1707] id=41, gunung=Merapi
# OK: jarak=98.45 km, luas=675.24 km2, sudut=234.71 deg, radius=49.67 km
#
# ----------------------------------------------------------------------
# [42/1707] id=42, gunung=Merapi
# Gagal: cdump.txt tidak memiliki data
#
# ----------------------------------------------------------------------
# [43/1707] id=43, gunung=Semeru
# OK: jarak=12.24 km, luas=153.36 km2, sudut=271.17 deg, radius=7.33 km
#
# ----------------------------------------------------------------------
# [44/1707] id=44, gunung=Semeru
# OK: jarak=22.66 km, luas=766.81 km2, sudut=298.80 deg, radius=12.19 km
#
# ----------------------------------------------------------------------
# [45/1707] id=45, gunung=Semeru
# OK: jarak=49.54 km, luas=1165.55 km2, sudut=90.65 deg, radius=25.25 km
#
# ----------------------------------------------------------------------
# [46/1707] id=46, gunung=Semeru
# OK: jarak=44.36 km, luas=828.10 km2, sudut=93.06 deg, radius=23.31 km
#
# ----------------------------------------------------------------------
# [47/1707] id=47, gunung=Semeru
# OK: jarak=12.60 km, luas=245.33 km2, sudut=175.40 deg, radius=7.11 km
#
# ----------------------------------------------------------------------
# [48/1707] id=48, gunung=Semeru
# OK: jarak=56.12 km, luas=1073.53 km2, sudut=88.45 deg, radius=29.84 km
#
# ----------------------------------------------------------------------
# [49/1707] id=49, gunung=Semeru
# OK: jarak=56.12 km, luas=1073.53 km2, sudut=88.45 deg, radius=29.84 km
#
# ----------------------------------------------------------------------
# [50/1707] id=50, gunung=Semeru
# OK: jarak=12.60 km, luas=184.00 km2, sudut=155.49 deg, radius=7.24 km
# Checkpoint tersimpan: d:\Projects\volcanic_ash\simulation\java_hysplit_filled.csv
#
# ----------------------------------------------------------------------
# [51/1707] id=51, gunung=Semeru
# OK: jarak=56.12 km, luas=1073.53 km2, sudut=88.45 deg, radius=29.84 km
#
# ----------------------------------------------------------------------
# [52/1707] id=52, gunung=Semeru
# OK: jarak=12.60 km, luas=184.00 km2, sudut=155.49 deg, radius=7.24 km
#
# ----------------------------------------------------------------------
# [53/1707] id=53, gunung=Semeru
# OK: jarak=7.98 km, luas=122.67 km2, sudut=148.57 deg, radius=4.87 km
#
# ----------------------------------------------------------------------
# [54/1707] id=54, gunung=Semeru
# OK: jarak=12.43 km, luas=184.01 km2, sudut=132.26 deg, radius=7.15 km
#
# ----------------------------------------------------------------------
# [55/1707] id=55, gunung=Semeru
# OK: jarak=12.43 km, luas=184.01 km2, sudut=132.26 deg, radius=7.15 km
#
# ----------------------------------------------------------------------
# [56/1707] id=56, gunung=Semeru
# OK: jarak=17.49 km, luas=184.01 km2, sudut=119.71 deg, radius=9.11 km
#
# ----------------------------------------------------------------------
# [57/1707] id=57, gunung=Semeru
# OK: jarak=49.54 km, luas=1134.95 km2, sudut=82.36 deg, radius=25.99 km
#
# ----------------------------------------------------------------------
# [58/1707] id=58, gunung=Semeru
# OK: jarak=52.21 km, luas=981.58 km2, sudut=85.14 deg, radius=26.27 km
#
# ----------------------------------------------------------------------
# [59/1707] id=59, gunung=Semeru
# OK: jarak=44.03 km, luas=736.05 km2, sudut=95.60 deg, radius=21.91 km
#
# ----------------------------------------------------------------------
# [60/1707] id=60, gunung=Semeru
# OK: jarak=15.80 km, luas=214.67 km2, sudut=142.58 deg, radius=8.62 km
#
# ----------------------------------------------------------------------
# [61/1707] id=61, gunung=Semeru
# OK: jarak=12.43 km, luas=184.01 km2, sudut=132.26 deg, radius=7.15 km
#
# ----------------------------------------------------------------------
# [62/1707] id=62, gunung=Semeru
# OK: jarak=12.43 km, luas=153.34 km2, sudut=122.17 deg, radius=7.43 km
#
# ----------------------------------------------------------------------
# [63/1707] id=63, gunung=Semeru
# OK: jarak=12.60 km, luas=184.00 km2, sudut=143.89 deg, radius=7.42 km
#
# ----------------------------------------------------------------------
# [64/1707] id=64, gunung=Semeru
# OK: jarak=12.60 km, luas=184.00 km2, sudut=155.49 deg, radius=7.24 km
#
# ----------------------------------------------------------------------
# [65/1707] id=65, gunung=Semeru
# OK: jarak=17.49 km, luas=184.01 km2, sudut=111.15 deg, radius=10.53 km
#
# ----------------------------------------------------------------------
# [66/1707] id=66, gunung=Semeru
# OK: jarak=16.51 km, luas=613.41 km2, sudut=109.68 deg, radius=8.31 km
#
# ----------------------------------------------------------------------
# [67/1707] id=67, gunung=Semeru
# OK: jarak=22.66 km, luas=214.71 km2, sudut=90.91 deg, radius=12.21 km
#
# ----------------------------------------------------------------------
# [68/1707] id=68, gunung=Semeru
# OK: jarak=17.36 km, luas=184.03 km2, sudut=93.87 deg, radius=10.47 km
#
# ----------------------------------------------------------------------
# [69/1707] id=69, gunung=Semeru
# OK: jarak=12.60 km, luas=153.33 km2, sudut=166.31 deg, radius=7.58 km
#
# ----------------------------------------------------------------------
# [70/1707] id=70, gunung=Semeru
# OK: jarak=12.60 km, luas=153.33 km2, sudut=149.87 deg, radius=6.42 km
#
# ----------------------------------------------------------------------
# [71/1707] id=71, gunung=Semeru
# OK: jarak=49.83 km, luas=1104.34 km2, sudut=81.88 deg, radius=26.82 km
#
# ----------------------------------------------------------------------
# [72/1707] id=72, gunung=Semeru
# OK: jarak=82.74 km, luas=2637.83 km2, sudut=85.60 deg, radius=47.56 km
#
# ----------------------------------------------------------------------
# [73/1707] id=73, gunung=Semeru
# OK: jarak=12.43 km, luas=153.34 km2, sudut=122.17 deg, radius=7.43 km
#
# ----------------------------------------------------------------------
# [74/1707] id=74, gunung=Semeru
# OK: jarak=50.73 km, luas=1165.62 km2, sudut=82.12 deg, radius=26.63 km
#
# ----------------------------------------------------------------------
# [75/1707] id=75, gunung=Semeru
# OK: jarak=60.78 km, luas=1196.22 km2, sudut=87.11 deg, radius=32.61 km
#
# ----------------------------------------------------------------------
# [76/1707] id=76, gunung=Semeru
# OK: jarak=12.60 km, luas=153.33 km2, sudut=149.87 deg, radius=6.42 km
#
# ----------------------------------------------------------------------
# [77/1707] id=77, gunung=Semeru
# OK: jarak=12.43 km, luas=184.01 km2, sudut=132.26 deg, radius=7.15 km
#
# ----------------------------------------------------------------------
# [78/1707] id=78, gunung=Semeru
# OK: jarak=12.43 km, luas=153.34 km2, sudut=122.17 deg, radius=7.43 km
#
# ----------------------------------------------------------------------
# [79/1707] id=79, gunung=Semeru
# OK: jarak=7.98 km, luas=122.67 km2, sudut=148.57 deg, radius=4.87 km
#
# ----------------------------------------------------------------------
# [80/1707] id=80, gunung=Semeru
# OK: jarak=12.60 km, luas=184.00 km2, sudut=155.49 deg, radius=7.24 km
#
# ----------------------------------------------------------------------
# [81/1707] id=81, gunung=Semeru
# OK: jarak=15.80 km, luas=214.67 km2, sudut=142.58 deg, radius=8.62 km
#
# ----------------------------------------------------------------------
# [82/1707] id=82, gunung=Semeru
# OK: jarak=60.78 km, luas=1196.22 km2, sudut=87.11 deg, radius=32.61 km
#
# ----------------------------------------------------------------------
# [83/1707] id=83, gunung=Semeru
# OK: jarak=24.57 km, luas=245.39 km2, sudut=80.64 deg, radius=12.65 km
#
# ----------------------------------------------------------------------
# [84/1707] id=84, gunung=Semeru
# OK: jarak=29.60 km, luas=306.74 km2, sudut=76.43 deg, radius=15.06 km
#
# ----------------------------------------------------------------------
# [85/1707] id=85, gunung=Semeru
# OK: jarak=12.60 km, luas=184.00 km2, sudut=155.49 deg, radius=7.24 km
#
# ----------------------------------------------------------------------
# [86/1707] id=86, gunung=Semeru
# OK: jarak=12.60 km, luas=184.00 km2, sudut=155.49 deg, radius=7.24 km
#
# ----------------------------------------------------------------------
# [87/1707] id=87, gunung=Semeru
# OK: jarak=12.60 km, luas=184.00 km2, sudut=155.49 deg, radius=7.24 km
#
# ----------------------------------------------------------------------
# [88/1707] id=88, gunung=Semeru
# OK: jarak=12.60 km, luas=153.33 km2, sudut=149.87 deg, radius=6.42 km
#
# ----------------------------------------------------------------------
# [89/1707] id=89, gunung=Semeru
# OK: jarak=12.60 km, luas=184.00 km2, sudut=155.49 deg, radius=7.24 km
#
# ----------------------------------------------------------------------
# [90/1707] id=90, gunung=Semeru
# OK: jarak=12.43 km, luas=153.34 km2, sudut=122.17 deg, radius=7.43 km
#
# ----------------------------------------------------------------------
# [91/1707] id=91, gunung=Semeru
# OK: jarak=12.43 km, luas=184.01 km2, sudut=132.26 deg, radius=7.15 km
#
# ----------------------------------------------------------------------
# [92/1707] id=92, gunung=Semeru
# OK: jarak=12.43 km, luas=153.34 km2, sudut=122.17 deg, radius=7.43 km
#
# ----------------------------------------------------------------------
# [93/1707] id=93, gunung=Semeru
# OK: jarak=44.36 km, luas=828.10 km2, sudut=93.06 deg, radius=23.31 km
#
# ----------------------------------------------------------------------
# [94/1707] id=94, gunung=Semeru
# OK: jarak=28.12 km, luas=398.67 km2, sudut=110.12 deg, radius=16.64 km
#
# ----------------------------------------------------------------------
# [95/1707] id=95, gunung=Semeru
# OK: jarak=44.41 km, luas=644.08 km2, sudut=95.20 deg, radius=25.55 km
#
# ----------------------------------------------------------------------
# [96/1707] id=96, gunung=Semeru
# OK: jarak=60.55 km, luas=1472.19 km2, sudut=91.97 deg, radius=34.04 km
#
# ----------------------------------------------------------------------
# [97/1707] id=97, gunung=Semeru
# OK: jarak=73.44 km, luas=2392.30 km2, sudut=90.93 deg, radius=40.34 km
#
# ----------------------------------------------------------------------
# [98/1707] id=98, gunung=Semeru
# OK: jarak=60.82 km, luas=1288.00 km2, sudut=99.83 deg, radius=32.03 km
#
# ----------------------------------------------------------------------
# [99/1707] id=99, gunung=Semeru
# OK: jarak=82.76 km, luas=2484.16 km2, sudut=93.14 deg, radius=43.23 km
#
# ----------------------------------------------------------------------
# [100/1707] id=100, gunung=Semeru
# OK: jarak=77.25 km, luas=1686.98 km2, sudut=93.74 deg, radius=40.77 km
# Checkpoint tersimpan: d:\Projects\volcanic_ash\simulation\java_hysplit_filled.csv
#
# ----------------------------------------------------------------------
# [101/1707] id=101, gunung=Semeru
# OK: jarak=34.91 km, luas=551.97 km2, sudut=111.28 deg, radius=20.81 km
#
# ----------------------------------------------------------------------
# [102/1707] id=102, gunung=Semeru
# OK: jarak=82.76 km, luas=1870.79 km2, sudut=96.20 deg, radius=43.85 km
#
# ----------------------------------------------------------------------
# [103/1707] id=103, gunung=Semeru
# OK: jarak=38.53 km, luas=460.00 km2, sudut=103.36 deg, radius=22.22 km
#
# ----------------------------------------------------------------------
# [104/1707] id=104, gunung=Semeru
# OK: jarak=38.90 km, luas=644.12 km2, sudut=87.99 deg, radius=19.56 km
#
# ----------------------------------------------------------------------
# [105/1707] id=105, gunung=Semeru
# OK: jarak=45.37 km, luas=644.20 km2, sudut=76.14 deg, radius=24.79 km
#
# ----------------------------------------------------------------------
# [106/1707] id=106, gunung=Semeru
# OK: jarak=28.04 km, luas=276.05 km2, sudut=89.36 deg, radius=15.06 km
#
# ----------------------------------------------------------------------
# [107/1707] id=107, gunung=Semeru
# OK: jarak=33.46 km, luas=306.72 km2, sudut=88.39 deg, radius=16.90 km
#
# ----------------------------------------------------------------------
# [108/1707] id=108, gunung=Semeru
# OK: jarak=38.90 km, luas=429.41 km2, sudut=88.38 deg, radius=21.93 km
#
# ----------------------------------------------------------------------
# [109/1707] id=109, gunung=Semeru
# OK: jarak=17.49 km, luas=276.00 km2, sudut=122.33 deg, radius=11.06 km
#
# ----------------------------------------------------------------------
# [110/1707] id=110, gunung=Semeru
# OK: jarak=22.02 km, luas=184.01 km2, sudut=105.95 deg, radius=12.13 km
#
# ----------------------------------------------------------------------
# [111/1707] id=111, gunung=Semeru
# OK: jarak=7.67 km, luas=214.69 km2, sudut=0.00 deg, radius=5.39 km
#
# ----------------------------------------------------------------------
# [112/1707] id=112, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [113/1707] id=113, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [114/1707] id=114, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [115/1707] id=115, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [116/1707] id=116, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [117/1707] id=117, gunung=Semeru
# OK: jarak=12.21 km, luas=122.70 km2, sudut=36.33 deg, radius=6.36 km
#
# ----------------------------------------------------------------------
# [118/1707] id=118, gunung=Semeru
# OK: jarak=7.67 km, luas=214.69 km2, sudut=0.00 deg, radius=5.39 km
#
# ----------------------------------------------------------------------
# [119/1707] id=119, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [120/1707] id=120, gunung=Semeru
# OK: jarak=12.21 km, luas=184.05 km2, sudut=319.63 deg, radius=6.98 km
#
# ----------------------------------------------------------------------
# [121/1707] id=121, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [122/1707] id=122, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [123/1707] id=123, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=69.06 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [124/1707] id=124, gunung=Semeru
# OK: jarak=7.67 km, luas=153.35 km2, sudut=258.70 deg, radius=4.90 km
#
# ----------------------------------------------------------------------
# [125/1707] id=125, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [126/1707] id=126, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [127/1707] id=127, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [128/1707] id=128, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [129/1707] id=129, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [130/1707] id=130, gunung=Semeru
# OK: jarak=12.21 km, luas=153.37 km2, sudut=24.29 deg, radius=7.27 km
#
# ----------------------------------------------------------------------
# [131/1707] id=131, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [132/1707] id=132, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=11.31 deg, radius=10.42 km
#
# ----------------------------------------------------------------------
# [133/1707] id=133, gunung=Semeru
# OK: jarak=7.67 km, luas=214.69 km2, sudut=0.00 deg, radius=5.39 km
#
# ----------------------------------------------------------------------
# [134/1707] id=134, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [135/1707] id=135, gunung=Semeru
# OK: jarak=7.67 km, luas=92.02 km2, sudut=314.14 deg, radius=4.41 km
#
# ----------------------------------------------------------------------
# [136/1707] id=136, gunung=Semeru
# OK: jarak=7.67 km, luas=92.02 km2, sudut=314.14 deg, radius=4.41 km
#
# ----------------------------------------------------------------------
# [137/1707] id=137, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [138/1707] id=138, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [139/1707] id=139, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [140/1707] id=140, gunung=Semeru
# OK: jarak=7.67 km, luas=153.36 km2, sudut=49.28 deg, radius=4.85 km
#
# ----------------------------------------------------------------------
# [141/1707] id=141, gunung=Semeru
# OK: jarak=5.51 km, luas=306.71 km2, sudut=223.87 deg, radius=2.86 km
#
# ----------------------------------------------------------------------
# [142/1707] id=142, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [143/1707] id=143, gunung=Semeru
# OK: jarak=7.67 km, luas=92.02 km2, sudut=314.14 deg, radius=4.41 km
#
# ----------------------------------------------------------------------
# [144/1707] id=144, gunung=Semeru
# OK: jarak=12.21 km, luas=122.70 km2, sudut=36.33 deg, radius=6.36 km
#
# ----------------------------------------------------------------------
# [145/1707] id=145, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [146/1707] id=146, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [147/1707] id=147, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=11.31 deg, radius=10.42 km
#
# ----------------------------------------------------------------------
# [148/1707] id=148, gunung=Semeru
# OK: jarak=7.98 km, luas=245.36 km2, sudut=239.27 deg, radius=5.71 km
#
# ----------------------------------------------------------------------
# [149/1707] id=149, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [150/1707] id=150, gunung=Semeru
# OK: jarak=7.67 km, luas=92.02 km2, sudut=314.14 deg, radius=4.41 km
# Checkpoint tersimpan: d:\Projects\volcanic_ash\simulation\java_hysplit_filled.csv
#
# ----------------------------------------------------------------------
# [151/1707] id=151, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [152/1707] id=152, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [153/1707] id=153, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [154/1707] id=154, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [155/1707] id=155, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [156/1707] id=156, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [157/1707] id=157, gunung=Semeru
# OK: jarak=17.36 km, luas=214.73 km2, sudut=18.13 deg, radius=10.02 km
#
# ----------------------------------------------------------------------
# [158/1707] id=158, gunung=Semeru
# OK: jarak=12.21 km, luas=122.70 km2, sudut=36.33 deg, radius=6.36 km
#
# ----------------------------------------------------------------------
# [159/1707] id=159, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [160/1707] id=160, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [161/1707] id=161, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [162/1707] id=162, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=290.94 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [163/1707] id=163, gunung=Semeru
# OK: jarak=12.21 km, luas=184.05 km2, sudut=319.63 deg, radius=6.98 km
#
# ----------------------------------------------------------------------
# [164/1707] id=164, gunung=Semeru
# OK: jarak=12.21 km, luas=153.37 km2, sudut=335.71 deg, radius=7.27 km
#
# ----------------------------------------------------------------------
# [165/1707] id=165, gunung=Semeru
# OK: jarak=12.21 km, luas=153.37 km2, sudut=335.71 deg, radius=7.27 km
#
# ----------------------------------------------------------------------
# [166/1707] id=166, gunung=Semeru
# OK: jarak=12.21 km, luas=153.37 km2, sudut=335.71 deg, radius=7.27 km
#
# ----------------------------------------------------------------------
# [167/1707] id=167, gunung=Semeru
# OK: jarak=12.21 km, luas=153.37 km2, sudut=24.29 deg, radius=7.27 km
#
# ----------------------------------------------------------------------
# [168/1707] id=168, gunung=Semeru
# OK: jarak=12.21 km, luas=153.37 km2, sudut=24.29 deg, radius=7.27 km
#
# ----------------------------------------------------------------------
# [169/1707] id=169, gunung=Semeru
# OK: jarak=12.21 km, luas=153.37 km2, sudut=24.29 deg, radius=7.27 km
#
# ----------------------------------------------------------------------
# [170/1707] id=170, gunung=Semeru
# OK: jarak=12.21 km, luas=153.37 km2, sudut=24.29 deg, radius=7.27 km
#
# ----------------------------------------------------------------------
# [171/1707] id=171, gunung=Semeru
# OK: jarak=7.98 km, luas=92.01 km2, sudut=165.79 deg, radius=4.66 km
#
# ----------------------------------------------------------------------
# [172/1707] id=172, gunung=Semeru
# OK: jarak=7.98 km, luas=92.01 km2, sudut=165.79 deg, radius=4.66 km
#
# ----------------------------------------------------------------------
# [173/1707] id=173, gunung=Semeru
# OK: jarak=7.98 km, luas=92.01 km2, sudut=136.24 deg, radius=4.57 km
#
# ----------------------------------------------------------------------
# [174/1707] id=174, gunung=Semeru
# OK: jarak=7.98 km, luas=92.01 km2, sudut=136.24 deg, radius=4.57 km
#
# ----------------------------------------------------------------------
# [175/1707] id=175, gunung=Semeru
# OK: jarak=7.98 km, luas=122.67 km2, sudut=148.57 deg, radius=4.87 km
#
# ----------------------------------------------------------------------
# [176/1707] id=176, gunung=Semeru
# OK: jarak=5.51 km, luas=306.71 km2, sudut=136.13 deg, radius=2.86 km
#
# ----------------------------------------------------------------------
# [177/1707] id=177, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=69.06 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [178/1707] id=178, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=69.06 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [179/1707] id=179, gunung=Semeru
# OK: jarak=7.67 km, luas=122.69 km2, sudut=69.06 deg, radius=4.68 km
#
# ----------------------------------------------------------------------
# [180/1707] id=180, gunung=Semeru
# OK: jarak=12.24 km, luas=122.69 km2, sudut=87.95 deg, radius=6.41 km
#
# ----------------------------------------------------------------------
# [181/1707] id=181, gunung=Semeru
# OK: jarak=12.24 km, luas=460.09 km2, sudut=336.29 deg, radius=8.22 km
#
# ----------------------------------------------------------------------
# [182/1707] id=182, gunung=Semeru
# OK: jarak=17.36 km, luas=521.46 km2, sudut=332.48 deg, radius=9.18 km
#
# ----------------------------------------------------------------------
# [183/1707] id=183, gunung=Semeru
# OK: jarak=23.32 km, luas=276.09 km2, sudut=50.03 deg, radius=11.31 km
#
# ----------------------------------------------------------------------
# [184/1707] id=184, gunung=Semeru
# OK: jarak=19.81 km, luas=214.73 km2, sudut=48.07 deg, radius=9.46 km
#
# ----------------------------------------------------------------------
# [185/1707] id=185, gunung=Semeru
# OK: jarak=19.81 km, luas=184.06 km2, sudut=37.94 deg, radius=10.12 km
#
# ----------------------------------------------------------------------
# [186/1707] id=186, gunung=Semeru
# OK: jarak=15.49 km, luas=153.37 km2, sudut=39.34 deg, radius=8.19 km
#
# ----------------------------------------------------------------------
# [187/1707] id=187, gunung=Semeru
# OK: jarak=15.49 km, luas=214.72 km2, sudut=54.55 deg, radius=8.38 km
#
# ----------------------------------------------------------------------
# [188/1707] id=188, gunung=Semeru
# OK: jarak=19.79 km, luas=245.39 km2, sudut=75.02 deg, radius=11.16 km
#
# ----------------------------------------------------------------------
# [189/1707] id=189, gunung=Semeru
# OK: jarak=24.57 km, luas=214.72 km2, sudut=75.25 deg, radius=12.48 km
#
# ----------------------------------------------------------------------
# [190/1707] id=190, gunung=Semeru
# OK: jarak=15.49 km, luas=153.37 km2, sudut=76.53 deg, radius=8.23 km
#
# ----------------------------------------------------------------------
# [191/1707] id=191, gunung=Semeru
# OK: jarak=12.24 km, luas=122.69 km2, sudut=87.95 deg, radius=6.41 km
#
# ----------------------------------------------------------------------
# [192/1707] id=192, gunung=Semeru
# OK: jarak=17.36 km, luas=184.03 km2, sudut=85.23 deg, radius=9.00 km
#
# ----------------------------------------------------------------------
# [193/1707] id=193, gunung=Semeru
# OK: jarak=17.36 km, luas=153.36 km2, sudut=83.58 deg, radius=8.60 km
#
# ----------------------------------------------------------------------
# [194/1707] id=194, gunung=Semeru
# OK: jarak=19.79 km, luas=245.39 km2, sudut=75.02 deg, radius=11.16 km
#
# ----------------------------------------------------------------------
# [195/1707] id=195, gunung=Semeru
# OK: jarak=19.79 km, luas=245.39 km2, sudut=75.02 deg, radius=11.16 km
#
# ----------------------------------------------------------------------
# [196/1707] id=196, gunung=Semeru
# OK: jarak=19.79 km, luas=214.72 km2, sudut=80.21 deg, radius=10.54 km
#
# ----------------------------------------------------------------------
# [197/1707] id=197, gunung=Semeru
# OK: jarak=19.79 km, luas=184.05 km2, sudut=77.80 deg, radius=10.46 km
#
# ----------------------------------------------------------------------
# [198/1707] id=198, gunung=Semeru
# OK: jarak=17.36 km, luas=214.71 km2, sudut=86.22 deg, radius=10.07 km
#
# ----------------------------------------------------------------------
# [199/1707] id=199, gunung=Semeru
# OK: jarak=12.21 km, luas=122.70 km2, sudut=323.67 deg, radius=6.36 km
#
# ----------------------------------------------------------------------
# [200/1707] id=200, gunung=Semeru
# OK: jarak=17.36 km, luas=153.38 km2, sudut=329.65 deg, radius=8.56 km
# Checkpoint tersimpan: d:\Projects\volcanic_ash\simulation\java_hysplit_filled.csv
#
# ----------------------------------------------------------------------
# [201/1707] id=201, gunung=Semeru
# OK: jarak=17.36 km, luas=398.79 km2, sudut=353.10 deg, radius=10.05 km
#
# ----------------------------------------------------------------------
# [202/1707] id=202, gunung=Semeru
# OK: jarak=15.49 km, luas=245.39 km2, sudut=299.20 deg, radius=8.71 km
#
# ----------------------------------------------------------------------
# [203/1707] id=203, gunung=Semeru
# OK: jarak=12.21 km, luas=122.70 km2, sudut=323.67 deg, radius=6.36 km
#
# ----------------------------------------------------------------------
# [204/1707] id=204, gunung=Semeru
# OK: jarak=17.36 km, luas=276.09 km2, sudut=357.04 deg, radius=10.01 km
#
# ----------------------------------------------------------------------
# [205/1707] id=205, gunung=Semeru
# OK: jarak=15.49 km, luas=245.39 km2, sudut=314.32 deg, radius=8.70 km
#
# ----------------------------------------------------------------------
# [206/1707] id=206, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [207/1707] id=207, gunung=Semeru
# OK: jarak=12.21 km, luas=153.37 km2, sudut=335.71 deg, radius=7.27 km
#
# ----------------------------------------------------------------------
# [208/1707] id=208, gunung=Semeru
# OK: jarak=17.36 km, luas=214.73 km2, sudut=341.87 deg, radius=10.02 km
#
# ----------------------------------------------------------------------
# [209/1707] id=209, gunung=Semeru
# OK: jarak=12.21 km, luas=214.72 km2, sudut=360.00 deg, radius=8.03 km
#
# ----------------------------------------------------------------------
# [210/1707] id=210, gunung=Semeru
# OK: jarak=17.36 km, luas=276.09 km2, sudut=357.04 deg, radius=10.01 km
#
# ----------------------------------------------------------------------
# [211/1707] id=211, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [212/1707] id=212, gunung=Semeru
# OK: jarak=12.21 km, luas=153.37 km2, sudut=24.29 deg, radius=7.27 km
#
# ----------------------------------------------------------------------
# [213/1707] id=213, gunung=Semeru
# OK: jarak=17.36 km, luas=276.09 km2, sudut=357.04 deg, radius=10.01 km
#
# ----------------------------------------------------------------------
# [214/1707] id=214, gunung=Semeru
# OK: jarak=17.36 km, luas=153.38 km2, sudut=329.65 deg, radius=8.56 km
#
# ----------------------------------------------------------------------
# [215/1707] id=215, gunung=Semeru
# OK: jarak=17.36 km, luas=276.09 km2, sudut=357.04 deg, radius=10.01 km
#
# ----------------------------------------------------------------------
# [216/1707] id=216, gunung=Semeru
# OK: jarak=12.21 km, luas=153.37 km2, sudut=335.71 deg, radius=7.27 km
#
# ----------------------------------------------------------------------
# [217/1707] id=217, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [218/1707] id=218, gunung=Semeru
# OK: jarak=12.21 km, luas=276.07 km2, sudut=360.00 deg, radius=7.47 km
#
# ----------------------------------------------------------------------
# [219/1707] id=219, gunung=Semeru
# OK: jarak=17.36 km, luas=368.11 km2, sudut=360.00 deg, radius=9.87 km
#
# ----------------------------------------------------------------------
# [220/1707] id=220, gunung=Semeru
# OK: jarak=12.21 km, luas=122.70 km2, sudut=323.67 deg, radius=6.36 km
#
# ----------------------------------------------------------------------
# [221/1707] id=221, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [222/1707] id=222, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [223/1707] id=223, gunung=Semeru
# OK: jarak=17.36 km, luas=214.73 km2, sudut=341.87 deg, radius=10.02 km
#
# ----------------------------------------------------------------------
# [224/1707] id=224, gunung=Semeru
# OK: jarak=12.21 km, luas=184.05 km2, sudut=348.35 deg, radius=8.09 km
#
# ----------------------------------------------------------------------
# [225/1707] id=225, gunung=Semeru
# OK: jarak=17.36 km, luas=276.09 km2, sudut=357.04 deg, radius=10.01 km
#
# ----------------------------------------------------------------------
# [226/1707] id=226, gunung=Semeru
# OK: jarak=12.21 km, luas=122.70 km2, sudut=323.67 deg, radius=6.36 km
#
# ----------------------------------------------------------------------
# [227/1707] id=227, gunung=Semeru
# OK: jarak=12.21 km, luas=122.70 km2, sudut=323.67 deg, radius=6.36 km
#
# ----------------------------------------------------------------------
# [228/1707] id=228, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [229/1707] id=229, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [230/1707] id=230, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [231/1707] id=231, gunung=Semeru
# OK: jarak=12.21 km, luas=153.37 km2, sudut=5.88 deg, radius=7.27 km
#
# ----------------------------------------------------------------------
# [232/1707] id=232, gunung=Semeru
# OK: jarak=17.36 km, luas=214.73 km2, sudut=341.87 deg, radius=10.02 km
#
# ----------------------------------------------------------------------
# [233/1707] id=233, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [234/1707] id=234, gunung=Semeru
# OK: jarak=12.21 km, luas=214.72 km2, sudut=360.00 deg, radius=8.03 km
#
# ----------------------------------------------------------------------
# [235/1707] id=235, gunung=Semeru
# OK: jarak=15.49 km, luas=214.72 km2, sudut=305.45 deg, radius=8.38 km
#
# ----------------------------------------------------------------------
# [236/1707] id=236, gunung=Semeru
# OK: jarak=12.21 km, luas=122.70 km2, sudut=323.67 deg, radius=6.36 km
#
# ----------------------------------------------------------------------
# [237/1707] id=237, gunung=Semeru
# OK: jarak=15.49 km, luas=153.37 km2, sudut=320.66 deg, radius=8.19 km
#
# ----------------------------------------------------------------------
# [238/1707] id=238, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [239/1707] id=239, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [240/1707] id=240, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [241/1707] id=241, gunung=Semeru
# OK: jarak=12.21 km, luas=122.70 km2, sudut=346.60 deg, radius=7.17 km
#
# ----------------------------------------------------------------------
# [242/1707] id=242, gunung=Semeru
# OK: jarak=17.36 km, luas=276.09 km2, sudut=357.04 deg, radius=10.01 km
#
# ----------------------------------------------------------------------
# [243/1707] id=243, gunung=Semeru
# OK: jarak=15.49 km, luas=153.37 km2, sudut=320.66 deg, radius=8.19 km
#
# ----------------------------------------------------------------------
# [244/1707] id=244, gunung=Semeru
# OK: jarak=15.49 km, luas=153.37 km2, sudut=320.66 deg, radius=8.19 km
#
# ----------------------------------------------------------------------
# [245/1707] id=245, gunung=Semeru
# OK: jarak=12.21 km, luas=122.70 km2, sudut=323.67 deg, radius=6.36 km
#
# ----------------------------------------------------------------------
# [246/1707] id=246, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [247/1707] id=247, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [248/1707] id=248, gunung=Semeru
# OK: jarak=12.21 km, luas=122.70 km2, sudut=346.60 deg, radius=7.17 km
#
# ----------------------------------------------------------------------
# [249/1707] id=249, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [250/1707] id=250, gunung=Semeru
# OK: jarak=17.36 km, luas=153.38 km2, sudut=329.65 deg, radius=8.56 km
# Checkpoint tersimpan: d:\Projects\volcanic_ash\simulation\java_hysplit_filled.csv
#
# ----------------------------------------------------------------------
# [251/1707] id=251, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [252/1707] id=252, gunung=Semeru
# OK: jarak=10.90 km, luas=122.70 km2, sudut=337.07 deg, radius=6.03 km
#
# ----------------------------------------------------------------------
# [253/1707] id=253, gunung=Semeru
# OK: jarak=15.49 km, luas=214.72 km2, sudut=305.45 deg, radius=8.38 km
#
# ----------------------------------------------------------------------
# [254/1707] id=254, gunung=Semeru
# OK: jarak=15.49 km, luas=153.37 km2, sudut=320.66 deg, radius=8.19 km
#
# ----------------------------------------------------------------------
# [255/1707] id=255, gunung=Semeru
# OK: jarak=15.49 km, luas=153.37 km2, sudut=320.66 deg, radius=8.19 km
#
# ----------------------------------------------------------------------
# [256/1707] id=256, gunung=Semeru
# OK: jarak=15.49 km, luas=153.37 km2, sudut=320.66 deg, radius=8.19 km
#
# ----------------------------------------------------------------------
# [257/1707] id=257, gunung=Semeru
# OK: jarak=12.21 km, luas=122.70 km2, sudut=323.67 deg, radius=6.36 km
#
# ----------------------------------------------------------------------
# [258/1707] id=258, gunung=Semeru
# OK: jarak=10.90 km, luas=460.11 km2, sudut=0.00 deg, radius=5.49 km
#
# ----------------------------------------------------------------------
# [259/1707] id=259, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [260/1707] id=260, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [261/1707] id=261, gunung=Semeru
# OK: jarak=17.36 km, luas=153.38 km2, sudut=329.65 deg, radius=8.56 km
#
# ----------------------------------------------------------------------
# [262/1707] id=262, gunung=Semeru
# OK: jarak=17.36 km, luas=153.38 km2, sudut=329.65 deg, radius=8.56 km
#
# ----------------------------------------------------------------------
# [263/1707] id=263, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [264/1707] id=264, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ----------------------------------------------------------------------
# [265/1707] id=265, gunung=Semeru
# OK: jarak=16.46 km, luas=306.76 km2, sudut=360.00 deg, radius=8.37 km
#
# ----------------------------------------------------------------------
# [266/1707] id=266, gunung=Semeru
# OK: jarak=15.49 km, luas=153.37 km2, sudut=320.66 deg, radius=8.19 km
#
# ----------------------------------------------------------------------
# [267/1707] id=267, gunung=Semeru
# OK: jarak=15.49 km, luas=153.37 km2, sudut=320.66 deg, radius=8.19 km
#
# ----------------------------------------------------------------------
# [268/1707] id=268, gunung=Semeru
# OK: jarak=17.36 km, luas=153.38 km2, sudut=329.65 deg, radius=8.56 km
#
# ----------------------------------------------------------------------
# [269/1707] id=269, gunung=Semeru
# OK: jarak=17.36 km, luas=153.38 km2, sudut=329.65 deg, radius=8.56 km
#
# ----------------------------------------------------------------------
# [270/1707] id=270, gunung=Semeru
# OK: jarak=12.21 km, luas=122.70 km2, sudut=346.60 deg, radius=7.17 km
#
# ----------------------------------------------------------------------
# [271/1707] id=271, gunung=Semeru
# OK: jarak=17.36 km, luas=184.06 km2, sudut=337.22 deg, radius=8.95 km
#
# ...
# [1620/1707] id=1623, gunung=Bromo
# OK: jarak=43.03 km, luas=368.09 km2, sudut=235.98 deg, radius=19.76 km
#
# ----------------------------------------------------------------------
# [1621/1707] id=1624, gunung=Bromo
# OK: jarak=78.40 km, luas=1011.99 km2, sudut=237.77 deg, radius=43.21 km
#
# ----------------------------------------------------------------------
# [1622/1707] id=1625, gunung=Bromo
# OK: jarak=29.70 km, luas=306.74 km2, sudut=203.41 deg, radius=15.05 km
#
# ----------------------------------------------------------------------
# [1623/1707] id=1626, gunung=Bromo
# OK: jarak=62.43 km, luas=674.70 km2, sudut=228.82 deg, radius=30.52 km
#
# ----------------------------------------------------------------------
# [1624/1707] id=1627, gunung=Bromo
# OK: jarak=31.14 km, luas=306.76 km2, sudut=235.63 deg, radius=14.82 km
#
# ----------------------------------------------------------------------
# [1625/1707] id=1628, gunung=Bromo
# OK: jarak=12.21 km, luas=153.40 km2, sudut=204.29 deg, radius=7.27 km
#
# ----------------------------------------------------------------------
# [1626/1707] id=1629, gunung=Bromo
# OK: jarak=31.14 km, luas=306.76 km2, sudut=225.80 deg, radius=14.83 km
#
# ----------------------------------------------------------------------
# [1627/1707] id=1630, gunung=Bromo
# OK: jarak=82.73 km, luas=1257.24 km2, sudut=234.81 deg, radius=47.40 km
#
# ----------------------------------------------------------------------
# [1628/1707] id=1631, gunung=Bromo
# OK: jarak=29.70 km, luas=306.74 km2, sudut=203.41 deg, radius=15.05 km
#
# ----------------------------------------------------------------------
# [1629/1707] id=1632, gunung=Bromo
# OK: jarak=46.79 km, luas=674.79 km2, sudut=229.50 deg, radius=24.84 km
#
# ----------------------------------------------------------------------
# [1630/1707] id=1633, gunung=Bromo
# OK: jarak=58.68 km, luas=644.03 km2, sudut=226.27 deg, radius=31.00 km
#
# ----------------------------------------------------------------------
# [1631/1707] id=1634, gunung=Bromo
# OK: jarak=29.70 km, luas=306.74 km2, sudut=203.41 deg, radius=15.05 km
#
# ----------------------------------------------------------------------
# [1632/1707] id=1635, gunung=Bromo
# OK: jarak=35.29 km, luas=398.76 km2, sudut=221.92 deg, radius=18.49 km
#
# ----------------------------------------------------------------------
# [1633/1707] id=1636, gunung=Bromo
# OK: jarak=35.29 km, luas=398.76 km2, sudut=221.92 deg, radius=18.49 km
#
# ----------------------------------------------------------------------
# [1634/1707] id=1637, gunung=Bromo
# OK: jarak=12.21 km, luas=122.72 km2, sudut=216.32 deg, radius=6.36 km
#
# ----------------------------------------------------------------------
# [1635/1707] id=1638, gunung=Bromo
# OK: jarak=35.29 km, luas=398.76 km2, sudut=221.92 deg, radius=18.49 km
#
# ----------------------------------------------------------------------
# [1636/1707] id=1639, gunung=Bromo
# OK: jarak=38.97 km, luas=398.76 km2, sudut=222.91 deg, radius=20.33 km
#
# ----------------------------------------------------------------------
# [1637/1707] id=1640, gunung=Bromo
# OK: jarak=38.97 km, luas=398.76 km2, sudut=222.91 deg, radius=20.33 km
#
# ----------------------------------------------------------------------
# [1638/1707] id=1641, gunung=Bromo
# OK: jarak=59.60 km, luas=705.46 km2, sudut=239.24 deg, radius=32.08 km
#
# ----------------------------------------------------------------------
# [1639/1707] id=1642, gunung=Slamet
# OK: jarak=39.82 km, luas=368.88 km2, sudut=307.80 deg, radius=21.49 km
#
# ----------------------------------------------------------------------
# [1640/1707] id=1643, gunung=Raung
# OK: jarak=17.81 km, luas=214.70 km2, sudut=294.47 deg, radius=10.47 km
#
# ----------------------------------------------------------------------
# [1641/1707] id=1644, gunung=Raung
# OK: jarak=22.24 km, luas=766.74 km2, sudut=284.64 deg, radius=11.31 km
#
# ----------------------------------------------------------------------
# [1642/1707] id=1645, gunung=Raung
# OK: jarak=18.16 km, luas=245.40 km2, sudut=322.85 deg, radius=10.12 km
#
# ----------------------------------------------------------------------
# [1643/1707] id=1646, gunung=Raung
# OK: jarak=18.16 km, luas=276.08 km2, sudut=327.02 deg, radius=10.29 km
#
# ----------------------------------------------------------------------
# [1644/1707] id=1647, gunung=Raung
# OK: jarak=12.78 km, luas=153.36 km2, sudut=300.31 deg, radius=7.75 km
#
# ----------------------------------------------------------------------
# [1645/1707] id=1648, gunung=Raung
# OK: jarak=13.00 km, luas=153.37 km2, sudut=341.39 deg, radius=7.95 km
#
# ----------------------------------------------------------------------
# [1646/1707] id=1649, gunung=Raung
# OK: jarak=20.57 km, luas=276.08 km2, sudut=323.34 deg, radius=11.28 km
#
# ----------------------------------------------------------------------
# [1647/1707] id=1650, gunung=Raung
# OK: jarak=20.40 km, luas=245.39 km2, sudut=309.41 deg, radius=11.86 km
#
# ----------------------------------------------------------------------
# [1648/1707] id=1651, gunung=Raung
# OK: jarak=17.81 km, luas=276.06 km2, sudut=311.08 deg, radius=10.21 km
#
# ----------------------------------------------------------------------
# [1649/1707] id=1652, gunung=Raung
# OK: jarak=16.20 km, luas=184.04 km2, sudut=313.61 deg, radius=9.45 km
#
# ----------------------------------------------------------------------
# [1650/1707] id=1653, gunung=Raung
# OK: jarak=17.81 km, luas=214.70 km2, sudut=294.47 deg, radius=10.47 km
# Checkpoint tersimpan: d:\Projects\volcanic_ash\simulation\java_hysplit_filled.csv
#
# ----------------------------------------------------------------------
# [1651/1707] id=1654, gunung=Raung
# OK: jarak=18.03 km, luas=515.31 km2, sudut=348.19 deg, radius=10.15 km
#
# ----------------------------------------------------------------------
# [1652/1707] id=1655, gunung=Raung
# OK: jarak=17.81 km, luas=245.39 km2, sudut=305.37 deg, radius=10.72 km
#
# ----------------------------------------------------------------------
# [1653/1707] id=1656, gunung=Raung
# OK: jarak=24.42 km, luas=214.74 km2, sudut=335.53 deg, radius=13.03 km
#
# ----------------------------------------------------------------------
# [1654/1707] id=1657, gunung=Raung
# OK: jarak=12.78 km, luas=122.69 km2, sudut=307.52 deg, radius=6.87 km
#
# ----------------------------------------------------------------------
# [1655/1707] id=1658, gunung=Raung
# OK: jarak=20.57 km, luas=184.05 km2, sudut=331.71 deg, radius=10.81 km
#
# ----------------------------------------------------------------------
# [1656/1707] id=1659, gunung=Raung
# OK: jarak=24.42 km, luas=214.74 km2, sudut=335.53 deg, radius=13.03 km
#
# ----------------------------------------------------------------------
# [1657/1707] id=1660, gunung=Raung
# OK: jarak=20.57 km, luas=184.05 km2, sudut=331.71 deg, radius=10.81 km
#
# ----------------------------------------------------------------------
# [1658/1707] id=1661, gunung=Raung
# OK: jarak=16.20 km, luas=153.37 km2, sudut=309.35 deg, radius=8.74 km
#
# ----------------------------------------------------------------------
# [1659/1707] id=1662, gunung=Raung
# OK: jarak=17.81 km, luas=184.04 km2, sudut=305.99 deg, radius=10.25 km
#
# ----------------------------------------------------------------------
# [1660/1707] id=1663, gunung=Raung
# OK: jarak=17.81 km, luas=214.71 km2, sudut=301.15 deg, radius=10.39 km
#
# ----------------------------------------------------------------------
# [1661/1707] id=1664, gunung=Raung
# OK: jarak=16.20 km, luas=214.71 km2, sudut=319.94 deg, radius=8.97 km
#
# ----------------------------------------------------------------------
# [1662/1707] id=1665, gunung=Raung
# OK: jarak=18.16 km, luas=276.08 km2, sudut=334.14 deg, radius=10.79 km
#
# ----------------------------------------------------------------------
# [1663/1707] id=1666, gunung=Raung
# OK: jarak=20.40 km, luas=276.06 km2, sudut=307.56 deg, radius=11.03 km
#
# ----------------------------------------------------------------------
# [1664/1707] id=1667, gunung=Raung
# OK: jarak=12.78 km, luas=153.36 km2, sudut=300.31 deg, radius=7.75 km
#
# ----------------------------------------------------------------------
# [1665/1707] id=1668, gunung=Raung
# OK: jarak=16.20 km, luas=184.04 km2, sudut=323.79 deg, radius=8.34 km
#
# ----------------------------------------------------------------------
# [1666/1707] id=1669, gunung=Raung
# OK: jarak=12.78 km, luas=122.69 km2, sudut=307.52 deg, radius=6.87 km
#
# ----------------------------------------------------------------------
# [1667/1707] id=1670, gunung=Raung
# OK: jarak=16.20 km, luas=184.04 km2, sudut=313.61 deg, radius=9.45 km
#
# ----------------------------------------------------------------------
# [1668/1707] id=1671, gunung=Raung
# OK: jarak=16.20 km, luas=245.39 km2, sudut=324.99 deg, radius=9.31 km
#
# ----------------------------------------------------------------------
# [1669/1707] id=1672, gunung=Raung
# OK: jarak=12.78 km, luas=153.36 km2, sudut=300.31 deg, radius=7.75 km
#
# ----------------------------------------------------------------------
# [1670/1707] id=1673, gunung=Raung
# OK: jarak=20.57 km, luas=276.08 km2, sudut=315.58 deg, radius=10.51 km
#
# ----------------------------------------------------------------------
# [1671/1707] id=1674, gunung=Raung
# OK: jarak=17.81 km, luas=184.03 km2, sudut=298.46 deg, radius=9.42 km
#
# ----------------------------------------------------------------------
# [1672/1707] id=1675, gunung=Raung
# OK: jarak=12.78 km, luas=122.69 km2, sudut=307.52 deg, radius=6.87 km
#
# ----------------------------------------------------------------------
# [1673/1707] id=1676, gunung=Raung
# OK: jarak=12.78 km, luas=122.69 km2, sudut=307.52 deg, radius=6.87 km
#
# ----------------------------------------------------------------------
# [1674/1707] id=1677, gunung=Raung
# OK: jarak=12.78 km, luas=122.69 km2, sudut=307.52 deg, radius=6.87 km
#
# ----------------------------------------------------------------------
# [1675/1707] id=1678, gunung=Raung
# OK: jarak=12.78 km, luas=122.69 km2, sudut=307.52 deg, radius=6.87 km
#
# ----------------------------------------------------------------------
# [1676/1707] id=1679, gunung=Raung
# OK: jarak=17.81 km, luas=245.39 km2, sudut=297.34 deg, radius=11.18 km
#
# ----------------------------------------------------------------------
# [1677/1707] id=1680, gunung=Raung
# OK: jarak=31.06 km, luas=1214.81 km2, sudut=346.82 deg, radius=14.92 km
#
# ----------------------------------------------------------------------
# [1678/1707] id=1681, gunung=Raung
# OK: jarak=16.20 km, luas=214.71 km2, sudut=319.94 deg, radius=8.97 km
#
# ----------------------------------------------------------------------
# [1679/1707] id=1682, gunung=Raung
# OK: jarak=27.39 km, luas=1288.20 km2, sudut=344.72 deg, radius=14.36 km
#
# ----------------------------------------------------------------------
# [1680/1707] id=1683, gunung=Raung
# OK: jarak=28.40 km, luas=1472.41 km2, sudut=350.52 deg, radius=15.43 km
#
# ----------------------------------------------------------------------
# [1681/1707] id=1684, gunung=Raung
# OK: jarak=17.81 km, luas=153.36 km2, sudut=303.81 deg, radius=9.06 km
#
# ----------------------------------------------------------------------
# [1682/1707] id=1685, gunung=Raung
# OK: jarak=17.81 km, luas=184.03 km2, sudut=298.46 deg, radius=9.42 km
#
# ----------------------------------------------------------------------
# [1683/1707] id=1686, gunung=Raung
# OK: jarak=16.74 km, luas=613.40 km2, sudut=288.35 deg, radius=8.58 km
#
# ----------------------------------------------------------------------
# [1684/1707] id=1687, gunung=Raung
# OK: jarak=6.12 km, luas=306.72 km2, sudut=348.47 deg, radius=3.36 km
#
# ----------------------------------------------------------------------
# [1685/1707] id=1688, gunung=Raung
# OK: jarak=11.68 km, luas=460.10 km2, sudut=351.99 deg, radius=6.13 km
#
# ----------------------------------------------------------------------
# [1686/1707] id=1689, gunung=Raung
# OK: jarak=192.77 km, luas=2117.24 km2, sudut=282.95 deg, radius=106.62 km
#
# ----------------------------------------------------------------------
# [1687/1707] id=1690, gunung=Raung
# OK: jarak=203.97 km, luas=1226.87 km2, sudut=270.79 deg, radius=110.59 km
#
# ----------------------------------------------------------------------
# [1688/1707] id=1691, gunung=Raung
# OK: jarak=143.81 km, luas=1626.48 km2, sudut=290.78 deg, radius=72.53 km
#
# ----------------------------------------------------------------------
# [1689/1707] id=1692, gunung=Raung
# OK: jarak=187.46 km, luas=1619.35 km2, sudut=267.14 deg, radius=100.47 km
#
# ----------------------------------------------------------------------
# [1690/1707] id=1693, gunung=Raung
# OK: jarak=127.36 km, luas=1288.37 km2, sudut=276.68 deg, radius=66.79 km
#
# ----------------------------------------------------------------------
# [1691/1707] id=1694, gunung=Raung
# OK: jarak=143.81 km, luas=1626.48 km2, sudut=290.78 deg, radius=72.53 km
#
# ----------------------------------------------------------------------
# [1692/1707] id=1695, gunung=Raung
# OK: jarak=143.41 km, luas=1779.60 km2, sudut=283.90 deg, radius=72.59 km
#
# ----------------------------------------------------------------------
# [1693/1707] id=1696, gunung=Raung
# OK: jarak=218.56 km, luas=3252.58 km2, sudut=280.16 deg, radius=122.81 km
#
# ----------------------------------------------------------------------
# [1694/1707] id=1697, gunung=Raung
# OK: jarak=193.49 km, luas=4586.43 km2, sudut=262.58 deg, radius=109.60 km
#
# ----------------------------------------------------------------------
# [1695/1707] id=1698, gunung=Raung
# OK: jarak=105.31 km, luas=785.04 km2, sudut=268.49 deg, radius=57.57 km
#
# ----------------------------------------------------------------------
# [1696/1707] id=1699, gunung=Raung
# OK: jarak=162.14 km, luas=3161.09 km2, sudut=288.10 deg, radius=97.16 km
#
# ----------------------------------------------------------------------
# [1697/1707] id=1700, gunung=Raung
# OK: jarak=166.85 km, luas=4822.05 km2, sudut=318.93 deg, radius=95.69 km
#
# ----------------------------------------------------------------------
# [1698/1707] id=1701, gunung=Raung
# OK: jarak=103.29 km, luas=2762.62 km2, sudut=318.16 deg, radius=57.65 km
#
# ----------------------------------------------------------------------
# [1699/1707] id=1702, gunung=Raung
# OK: jarak=140.91 km, luas=1320.30 km2, sudut=319.62 deg, radius=75.18 km
#
# ----------------------------------------------------------------------
# [1700/1707] id=1703, gunung=Raung
# OK: jarak=51.11 km, luas=398.76 km2, sudut=288.86 deg, radius=25.85 km
# Checkpoint tersimpan: d:\Projects\volcanic_ash\simulation\java_hysplit_filled.csv
#
# ----------------------------------------------------------------------
# [1701/1707] id=1704, gunung=Raung
# OK: jarak=127.23 km, luas=2673.20 km2, sudut=260.14 deg, radius=75.08 km
#
# ----------------------------------------------------------------------
# [1702/1707] id=1705, gunung=Raung
# OK: jarak=126.96 km, luas=3753.25 km2, sudut=265.59 deg, radius=77.03 km
#
# ----------------------------------------------------------------------
# [1703/1707] id=1706, gunung=Raung
# OK: jarak=12.78 km, luas=184.00 km2, sudut=268.10 deg, radius=7.75 km
#
# ----------------------------------------------------------------------
# [1704/1707] id=1707, gunung=Raung
# OK: jarak=17.81 km, luas=184.00 km2, sudut=262.28 deg, radius=9.06 km
#
# ----------------------------------------------------------------------
# [1705/1707] id=1708, gunung=Raung
# OK: jarak=27.38 km, luas=275.96 km2, sudut=219.87 deg, radius=15.24 km
#
# ----------------------------------------------------------------------
# [1706/1707] id=1709, gunung=Raung
# OK: jarak=23.06 km, luas=245.37 km2, sudut=293.25 deg, radius=12.04 km
#
# ----------------------------------------------------------------------
# [1707/1707] id=1710, gunung=Raung
# OK: jarak=27.38 km, luas=275.96 km2, sudut=219.87 deg, radius=15.24 km
#
# ======================================================================
# RINGKASAN
# ======================================================================
# Berhasil: 1704
# Gagal   : 3
# Output  : d:\Projects\volcanic_ash\simulation\java_hysplit_filled.csv
